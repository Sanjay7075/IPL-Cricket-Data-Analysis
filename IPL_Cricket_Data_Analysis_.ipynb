# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/matches.csv")
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df.isna().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'])  # Convert date format
df.head()
# Out:
#        id   season        city       date match_type player_of_match  \
# 0  335982  2007/08   Bangalore 2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh 2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi 2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai 2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata 2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
season_wise_matches = df.groupby("season")["id"].count().reset_index()
plt.figure(figsize=(10, 5))
sns.lineplot(x="season", y="id", data=season_wise_matches, marker="o", color="blue")
plt.title("Total Matches Per Season")
plt.xlabel("Season")
plt.ylabel("Number of Matches")
plt.show()

# %%
top_teams = df['winner'].value_counts().head(10)
plt.figure(figsize=(10, 5))
sns.barplot(x=top_teams.index, y=top_teams.values, palette="viridis")
plt.xticks(rotation=45)
plt.title("Top 10 IPL Teams with Most Wins")
plt.show()
# Out:
# <ipython-input-7-c3f8eaa8baf6>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_teams.index, y=top_teams.values, palette="viridis")

# %%
toss_decision = df.groupby("toss_decision")["winner"].count()
toss_decision.plot(kind="bar", color=["blue", "orange"])
plt.title("Toss Decision Impact on Wins")
plt.xlabel("Toss Decision")
plt.ylabel("Number of Wins")
plt.show()
